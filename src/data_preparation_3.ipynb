# %%
#imports
import numpy as np
import pandas as pd

# %% [markdown]
# Restaurants are organised by neighbourhood. There are a lot of neighborhoods
# in the data. Using the longitude and latitude of each restaurant, can you find
# other ways to organise restaurants together, e.g., using a clustering model?
# Can you find any interesting associations with other elements of the data using
# this clustering?

# %%
business = pd.read_csv("data/business.csv")
print(business.columns)
print(len(business))
business.head(2)
# Out:
# Index(['address', 'AcceptsInsurance', 'AgesAllowed', 'Alcohol',
#        'Ambience.casual', 'Ambience.classy', 'Ambience.hipster',
#        'Ambience.intimate', 'Ambience.romantic', 'Ambience.touristy',
#        'Ambience.trendy', 'Ambience.upscale', 'BestNights.friday',
#        'BestNights.monday', 'BestNights.saturday', 'BestNights.sunday',
#        'BestNights.thursday', 'BestNights.tuesday', 'BestNights.wednesday',
#        'BikeParking', 'BusinessAcceptsCreditCards', 'BusinessParking.garage',
#        'BusinessParking.lot', 'BusinessParking.street',
#        'BusinessParking.valet', 'BusinessParking.validated',
#        'ByAppointmentOnly', 'Caters', 'CoatCheck',
#        'DietaryRestrictions.dairy-free', 'DietaryRestrictions.gluten-free',
#        'DietaryRestrictions.halal', 'DietaryRestrictions.kosher',
#        'DietaryRestrictions.soy-free', 'DietaryRestrictions.vegan',
#        'DietaryRestrictions.vegetarian', 'DogsAllowed', 'DriveThru',
# ...

# %%
business = pd.read_csv("data/business.csv")
question3 = business[['business_id','name','latitude','longitude','review_count','stars']]
question3.to_csv("data/question3.csv",index=False)
question3.head()
# Out:
#               business_id                               name  latitude  \
# 0  l09JfMeQ6ynYs5MCJtrcmQ                     Alize Catering  43.71140
# 1  1K4qrnfyzKzGgJPBEcJaNQ             Chula Taberna Mexicana  43.66926
# 2  nbhBRhZtdaZmMMeb2i02pg                    Sunnyside Grill  43.78182
# 3  FXHfcFVEfI1vVngW2gVOpw  Bampot House of Tea & Board Games  43.66158
# 4  VXH7zXcZzXlmAVN8GSjGRQ                       Thai Express  43.77488
#
#    longitude  review_count  stars
# 0  -79.39934            12    3.0
# 1  -79.33590            39    3.5
# 2  -79.49043             3    5.0
# 3  -79.40888            55    4.0
# 4  -79.49462             5    3.0
